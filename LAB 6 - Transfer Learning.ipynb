# %% [markdown]
# # ***Q1***

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# Define the CNN architecture
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 64 * 7 * 7)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Load and preprocess the data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_set = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_set, batch_size=64, shuffle=True)

# Initialize the model, loss function, and optimizer
model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Print nodel's state_dict
print("Model's state_dict: ")
for param_tensor in model.state_dict().keys():
    print(param_tensor, "\t", model.state_dict()[param_tensor].size())
print()

# Print optimizer's state_dict
print("Optimizer's state_dict: ")
for var_name in optimizer.state_dict():
    print(var_name, "\t", optimizer.state_dict()[var_name])
    
# Train the model
EPOCHS = 2
for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch + 1))

torch.save(model, "./ModelFiles/model.pt")
# Out:
# Model's state_dict:
# conv1.weight 	 torch.Size([32, 1, 3, 3])
# conv1.bias 	 torch.Size([32])
# conv2.weight 	 torch.Size([64, 32, 3, 3])
# conv2.bias 	 torch.Size([64])
# fc1.weight 	 torch.Size([128, 3136])
# fc1.bias 	 torch.Size([128])
# fc2.weight 	 torch.Size([10, 128])
# fc2.bias 	 torch.Size([10])
#
# Optimizer's state_dict:
# state 	 {}
# param_groups 	 [{'lr': 0.001, 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False, 'maximize': False, 'foreach': None, 'capturable': False, 'differentiable': False, 'fused': None, 'params': [0, 1, 2, 3, 4, 5, 6, 7]}]
# EPOCH 1:
# EPOCH 2:

# %%
mnist_testset = datasets.FashionMNIST(root = './data', train = False, download = True, transform = transforms.ToTensor())
test_loader = DataLoader(mnist_testset, batch_size = 4, shuffle = False)
model = CNN()
model = torch.load("./ModelFiles/model.pt")
print("Model's state_dict:")
for param_tensor in model.state_dict().keys():
    print(param_tensor, "\t",model.state_dict()[param_tensor].size())
print()

model.eval()
correct = 0
total = 0
for i, vdata in enumerate(test_loader):
    tinputs, tlabels = vdata
    toutputs = model(tinputs)
    #Select the predicted class label which has the

        _, predicted = torch.max(toutputs, 1)
    print("True label:{}".format(tlabels))
    print('Predicted: {}'.format(predicted))
    # Total number of labels
    total += tlabels.size(0)
    # Total correct predictions
    correct += (predicted == tlabels).sum()
    
accuracy = 100.0 * correct / total
print("The overall accuracy is {}".format(accuracy))
# Out:
# Model's state_dict:
# conv1.weight 	 torch.Size([32, 1, 3, 3])
# conv1.bias 	 torch.Size([32])
# conv2.weight 	 torch.Size([64, 32, 3, 3])
# conv2.bias 	 torch.Size([64])
# fc1.weight 	 torch.Size([128, 3136])
# fc1.bias 	 torch.Size([128])
# fc2.weight 	 torch.Size([10, 128])
# fc2.bias 	 torch.Size([10])
#
# True label:tensor([9, 2, 1, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([6, 1, 4, 6])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([5, 7, 4, 5])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([7, 3, 4, 1])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([2, 4, 8, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([2, 5, 7, 9])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([1, 4, 6, 0])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([9, 3, 8, 8])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([3, 3, 8, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 5, 7, 9])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([6, 1, 3, 7])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([6, 7, 2, 1])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([2, 2, 4, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([5, 8, 2, 2])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([8, 4, 8, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 7, 8, 5])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 1, 2, 3])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([9, 8, 7, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([2, 6, 2, 3])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 2, 8, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([1, 8, 5, 9])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 0, 3, 2])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([0, 6, 5, 3])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([6, 7, 1, 8])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([0, 1, 4, 2])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([3, 6, 7, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([7, 8, 5, 9])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([9, 4, 2, 5])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 0, 5, 2])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 6, 7, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([0, 0, 9, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([3, 0, 8, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([1, 5, 4, 1])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([9, 1, 8, 6])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([2, 1, 2, 5])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([1, 0, 0, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([1, 6, 1, 6])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 2, 4, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([1, 4, 5, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([4, 7, 9, 3])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([7, 2, 3, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([0, 9, 4, 7])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([4, 2, 0, 5])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([2, 1, 2, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([3, 0, 9, 1])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 9, 3, 6])
# Predicted: tensor([8, 2, 0, 8])
# True label:tensor([7, 9, 9, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([4, 7, 1, 2])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([1, 6, 3, 2])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([8, 3, 6, 1])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([1, 0, 2, 9])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 4, 0, 7])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 8, 4, 1])
# Predicted: tensor([2, 0, 2, 8])
# True label:tensor([8, 4, 1, 3])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 6, 7, 2])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([8, 5, 2, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([7, 7, 6, 2])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([7, 0, 7, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 2, 9, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([5, 1, 4, 4])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([5, 6, 9, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([6, 8, 6, 4])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([2, 2, 9, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([6, 5, 5, 2])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([8, 5, 2, 3])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([0, 4, 8, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([0, 6, 3, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([9, 6, 1, 3])
# Predicted: tensor([2, 2, 2, 0])
# True label:tensor([0, 2, 3, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 3, 7, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 1, 6, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([0, 6, 6, 7])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([5, 4, 5, 9])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([5, 6, 5, 5])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([1, 9, 8, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 3, 6, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([0, 0, 2, 9])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 7, 1, 3])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([6, 4, 2, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([9, 1, 6, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([8, 2, 6, 5])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([4, 6, 7, 7])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 3, 3, 7])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([0, 7, 1, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([7, 2, 2, 3])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([4, 0, 3, 1])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 1, 9, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([9, 9, 1, 7])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([8, 3, 6, 0])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([2, 4, 8, 0])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([1, 2, 2, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([4, 7, 3, 2])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([2, 5, 0, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([9, 4, 0, 9])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([3, 9, 4, 2])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([5, 0, 2, 3])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 8, 1, 6])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([2, 6, 6, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([9, 5, 2, 0])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([4, 6, 1, 2])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([0, 9, 7, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([4, 4, 6, 6])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([2, 1, 0, 6])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([7, 2, 9, 4])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([2, 1, 5, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([5, 3, 8, 5])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 4, 4, 8])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([9, 8, 6, 2])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([4, 4, 2, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([1, 6, 1, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([0, 9, 8, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([6, 5, 3, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([9, 5, 3, 3])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([0, 1, 0, 2])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([9, 2, 0, 6])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([3, 4, 2, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([0, 3, 3, 8])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 8, 9, 4])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([0, 7, 6, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([4, 9, 2, 9])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 9, 3, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([5, 7, 8, 1])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([0, 0, 3, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([8, 9, 7, 9])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([1, 2, 7, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([2, 0, 5, 7])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([1, 8, 2, 2])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([2, 2, 4, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 1, 9, 8])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([5, 1, 9, 1])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([2, 8, 3, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 2, 4, 2])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([8, 8, 2, 0])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([5, 8, 8, 5])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([3, 9, 4, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([4, 4, 5, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([0, 1, 2, 0])
# Predicted: tensor([8, 2, 2, 0])
# True label:tensor([6, 9, 6, 1])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([5, 1, 1, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([9, 3, 4, 5])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([3, 6, 6, 6])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([4, 6, 0, 5])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([8, 3, 3, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([6, 7, 7, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([9, 0, 3, 8])
# Predicted: tensor([1, 8, 8, 2])
# True label:tensor([7, 6, 7, 9])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([3, 4, 6, 6])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([5, 0, 1, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([5, 9, 4, 6])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([5, 7, 8, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([2, 9, 7, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([1, 0, 9, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 9, 0, 7])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([6, 8, 2, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([0, 2, 3, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 2, 6, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([3, 0, 7, 8])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 2, 9, 4])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([2, 6, 6, 8])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([0, 4, 4, 4])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([7, 5, 8, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([9, 1, 0, 5])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([4, 4, 4, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 4, 5, 6])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([0, 4, 5, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([1, 3, 1, 1])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([6, 4, 3, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 8, 2, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([0, 4, 0, 8])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([5, 0, 8, 2])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([9, 0, 8, 9])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([6, 4, 2, 9])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([3, 4, 5, 0])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([9, 5, 3, 6])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 8, 3, 3])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([8, 1, 4, 0])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([9, 7, 9, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([8, 9, 1, 6])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 3, 0, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 7, 1, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 8, 5, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([6, 6, 6, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([1, 5, 9, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([2, 1, 6, 5])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([0, 0, 3, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([3, 8, 1, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 5, 7, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([8, 7, 2, 0])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([7, 3, 8, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 7, 6, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 6, 4, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([0, 6, 3, 6])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([8, 4, 0, 8])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 2, 4, 5])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([9, 1, 4, 4])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([9, 2, 1, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([9, 5, 8, 1])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([7, 7, 1, 1])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([1, 6, 9, 5])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([3, 8, 4, 2])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([7, 4, 8, 3])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([2, 4, 4, 7])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 4, 9, 3])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([5, 8, 5, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([7, 2, 8, 5])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([9, 3, 3, 6])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([7, 1, 7, 3])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([5, 4, 4, 5])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([8, 3, 7, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([2, 6, 1, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 2, 7, 1])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([3, 7, 5, 9])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([9, 1, 8, 2])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([5, 7, 1, 9])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([8, 1, 0, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([6, 1, 7, 1])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([1, 5, 7, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([5, 2, 2, 3])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 1, 1, 4])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([9, 4, 3, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 0, 8, 9])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([9, 6, 1, 3])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([4, 0, 0, 5])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([9, 2, 0, 5])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([5, 1, 5, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([8, 7, 5, 3])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([6, 4, 0, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([0, 6, 0, 2])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([5, 5, 1, 2])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([0, 9, 3, 7])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([8, 6, 8, 3])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([4, 7, 0, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([4, 8, 0, 3])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([4, 4, 3, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([9, 0, 6, 4])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([9, 1, 8, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 5, 5, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([0, 2, 1, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 4, 0, 0])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([6, 7, 5, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([3, 5, 9, 6])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([8, 0, 6, 4])
# Predicted: tensor([2, 8, 0, 2])
# True label:tensor([6, 2, 9, 6])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([7, 7, 1, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([2, 6, 5, 3])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([9, 9, 8, 8])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([3, 0, 2, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([6, 6, 3, 2])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([3, 5, 4, 9])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([3, 4, 7, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([0, 3, 5, 5])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([6, 0, 5, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([6, 3, 7, 5])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([1, 9, 8, 8])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([9, 9, 2, 7])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([2, 2, 3, 8])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([7, 6, 4, 5])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([4, 3, 6, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([4, 9, 3, 1])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 5, 0, 5])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([7, 5, 2, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 9, 6, 3])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([6, 0, 4, 5])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([0, 4, 9, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([6, 3, 6, 7])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([0, 2, 1, 1])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([4, 4, 8, 5])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 0, 1, 6])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([5, 1, 4, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([8, 4, 7, 7])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([3, 8, 1, 1])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([9, 8, 1, 3])
# Predicted: tensor([1, 2, 8, 2])
# True label:tensor([3, 7, 5, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([5, 7, 8, 9])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 3, 5, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([4, 4, 3, 8])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([4, 5, 5, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([7, 1, 5, 0])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([5, 4, 8, 6])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 1, 1, 7])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 6, 2, 7])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([0, 4, 8, 2])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([2, 6, 6, 6])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([4, 9, 6, 8])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([4, 5, 9, 0])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([3, 9, 4, 9])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([8, 7, 4, 2])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([2, 5, 3, 7])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([6, 7, 2, 9])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([3, 7, 0, 9])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([4, 8, 6, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([7, 6, 4, 6])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([2, 0, 7, 8])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([4, 2, 6, 5])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([5, 6, 4, 5])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([5, 8, 1, 1])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([7, 4, 6, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([6, 8, 7, 2])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([2, 1, 2, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([7, 6, 9, 8])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([5, 1, 1, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 0, 9, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([1, 9, 6, 5])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([5, 2, 0, 7])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([0, 2, 0, 1])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 1, 3, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([7, 2, 4, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([5, 2, 9, 0])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([3, 4, 4, 6])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([6, 5, 2, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 6, 1, 4])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 5, 4, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([8, 0, 2, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 6, 2, 6])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([8, 3, 8, 2])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([0, 4, 4, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 4, 5, 2])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([2, 3, 0, 1])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([9, 0, 9, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([9, 6, 5, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([2, 7, 3, 8])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 0, 8, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([7, 5, 5, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([5, 0, 6, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([3, 4, 4, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([8, 7, 1, 3])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([4, 0, 6, 5])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([1, 6, 7, 3])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([4, 8, 8, 2])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([8, 9, 4, 1])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([6, 5, 2, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([8, 5, 3, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([5, 4, 2, 8])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([9, 8, 4, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 8, 8, 2])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([0, 9, 4, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([8, 1, 3, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([1, 9, 2, 1])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([6, 2, 7, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([4, 6, 0, 4])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([4, 2, 4, 5])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([0, 2, 8, 3])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([7, 6, 4, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 5, 2, 8])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([2, 4, 3, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([2, 1, 7, 7])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([5, 4, 7, 2])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([4, 7, 3, 3])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([1, 3, 3, 6])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 1, 7, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([4, 7, 1, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 5, 8, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([4, 7, 9, 5])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([0, 7, 9, 5])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([1, 2, 9, 5])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 3, 9, 9])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([1, 2, 7, 8])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([0, 1, 7, 2])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([7, 1, 1, 5])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([5, 6, 4, 5])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([9, 5, 5, 2])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 9, 3, 8])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([5, 2, 0, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 5, 7, 8])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 2, 6, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([4, 7, 4, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 1, 7, 2])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 6, 8, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([8, 7, 1, 2])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 2, 9, 7])
# Predicted: tensor([8, 0, 8, 8])
# True label:tensor([5, 6, 1, 0])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 1, 2, 6])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([9, 3, 6, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([4, 3, 0, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 3, 6, 1])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([3, 5, 6, 5])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([0, 9, 1, 1])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([8, 2, 9, 5])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([0, 5, 4, 6])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 1, 1, 5])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 8, 9, 8])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([3, 8, 9, 2])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([6, 1, 1, 3])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 2, 7, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([9, 9, 2, 2])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 0, 1, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([9, 6, 3, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([2, 8, 1, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([0, 7, 9, 8])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([5, 8, 2, 6])
# Predicted: tensor([2, 2, 2, 0])
# True label:tensor([4, 0, 6, 5])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([8, 3, 8, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 7, 3, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 7, 0, 2])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([2, 5, 3, 5])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([1, 1, 7, 7])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([6, 3, 0, 4])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([2, 8, 6, 3])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([1, 4, 9, 9])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([4, 5, 2, 2])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 8, 0, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([9, 1, 2, 9])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([4, 7, 3, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([3, 3, 1, 8])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 5, 3, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([6, 3, 4, 3])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([2, 0, 2, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([3, 6, 8, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 7, 3, 1])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([7, 5, 8, 8])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([2, 0, 6, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([4, 6, 5, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([0, 6, 6, 7])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 3, 9, 2])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([5, 9, 7, 1])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([7, 2, 4, 5])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 3, 5, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([5, 0, 4, 4])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([1, 4, 4, 8])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([4, 5, 9, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([1, 1, 7, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([3, 5, 0, 3])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([9, 7, 5, 3])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 8, 8, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([1, 1, 6, 3])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([1, 6, 3, 4])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 9, 6, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 9, 4, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([6, 6, 1, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([9, 2, 9, 4])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 0, 7, 2])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 6, 2, 5])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([6, 1, 9, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 2, 9, 9])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([0, 8, 3, 6])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([6, 6, 0, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([6, 6, 6, 5])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([0, 2, 7, 8])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([7, 4, 6, 6])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([6, 5, 2, 4])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([2, 9, 5, 2])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([6, 7, 0, 1])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([9, 5, 5, 6])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 7, 5, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 0, 8, 4])
# Predicted: tensor([8, 8, 0, 2])
# True label:tensor([7, 9, 8, 2])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([4, 7, 3, 3])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 7, 7, 8])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([4, 9, 5, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([6, 5, 7, 5])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([1, 3, 0, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([9, 9, 8, 3])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 0, 3, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([9, 3, 4, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 9, 1, 5])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([7, 2, 7, 6])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 5, 3, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([5, 5, 4, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([7, 3, 3, 2])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([0, 2, 9, 9])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 3, 0, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([3, 8, 8, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([4, 1, 8, 2])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([3, 5, 0, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([4, 3, 0, 0])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([1, 0, 8, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([9, 0, 7, 0])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([7, 7, 1, 5])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([8, 7, 2, 9])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([9, 1, 2, 4])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([1, 1, 1, 8])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 1, 3, 7])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([5, 2, 0, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([4, 8, 9, 4])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([1, 3, 1, 9])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 1, 1, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 0, 9, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([7, 6, 0, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([2, 1, 1, 7])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([9, 4, 2, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([3, 6, 6, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 7, 2, 4])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 2, 3, 8])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 1, 8, 5])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 7, 7, 6])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([6, 2, 9, 6])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([6, 0, 5, 5])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([0, 2, 1, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 5, 9, 1])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([7, 2, 5, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([9, 8, 9, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([2, 8, 3, 2])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([3, 6, 0, 8])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([3, 8, 6, 8])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([6, 0, 8, 8])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([8, 2, 9, 3])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([2, 0, 8, 5])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([7, 0, 1, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([1, 9, 5, 1])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([3, 3, 6, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([8, 2, 1, 3])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([8, 8, 6, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 6, 6, 7])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([3, 3, 2, 4])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([6, 5, 5, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([2, 3, 7, 1])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([1, 7, 3, 8])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([7, 2, 2, 9])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 9, 9, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([1, 5, 1, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([8, 1, 4, 9])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 4, 0, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([7, 6, 9, 9])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([5, 5, 7, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 3, 3, 6])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([9, 8, 4, 2])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([2, 3, 9, 4])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([3, 6, 7, 3])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([0, 4, 8, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 7, 3, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 2, 2, 9])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([1, 9, 4, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([1, 6, 2, 8])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([8, 7, 7, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 2, 6, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 5, 8, 5])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([6, 0, 2, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([9, 2, 6, 1])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([1, 9, 3, 1])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([2, 2, 2, 3])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 5, 7, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([4, 4, 1, 2])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([3, 5, 4, 2])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([9, 1, 5, 9])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([3, 6, 6, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([0, 1, 7, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([4, 6, 7, 7])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([3, 0, 4, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 7, 8, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([2, 8, 0, 8])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([7, 4, 6, 2])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([7, 0, 9, 9])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([3, 1, 5, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([3, 1, 0, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 5, 9, 7])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([9, 8, 3, 5])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 3, 7, 9])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([3, 4, 6, 6])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([5, 7, 7, 6])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([3, 5, 3, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([1, 9, 4, 3])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([9, 5, 5, 7])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([2, 4, 9, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 1, 9, 7])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([1, 5, 0, 5])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([5, 0, 3, 5])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([0, 3, 3, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([4, 2, 6, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([5, 9, 2, 1])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([0, 5, 5, 8])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([5, 3, 7, 4])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([4, 3, 9, 6])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 0, 9, 1])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([4, 3, 1, 5])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([3, 8, 5, 1])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([1, 2, 9, 4])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([0, 5, 2, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([0, 2, 9, 8])
# Predicted: tensor([8, 0, 2, 2])
# True label:tensor([2, 4, 8, 3])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([8, 0, 2, 0])
# Predicted: tensor([2, 8, 0, 8])
# True label:tensor([0, 4, 8, 5])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([4, 9, 0, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([5, 8, 6, 9])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([1, 2, 7, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([1, 6, 6, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([6, 5, 0, 4])
# Predicted: tensor([2, 8, 8, 0])
# True label:tensor([8, 5, 5, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 3, 8, 6])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([3, 1, 9, 2])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([9, 7, 3, 6])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([4, 8, 3, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([8, 5, 6, 8])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([3, 3, 1, 4])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([2, 0, 4, 9])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([0, 2, 1, 9])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([9, 8, 1, 8])
# Predicted: tensor([2, 0, 8, 8])
# True label:tensor([8, 3, 3, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 5, 9, 6])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([6, 8, 7, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 0, 0, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 7, 5, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 9, 1, 6])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([4, 8, 9, 3])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 6, 0, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([4, 7, 8, 9])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([1, 8, 2, 5])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 3, 1, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 8, 3, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([7, 0, 1, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([1, 6, 4, 9])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([8, 9, 8, 8])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 9, 1, 8])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([4, 2, 7, 7])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([0, 5, 1, 1])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([0, 6, 4, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([0, 4, 3, 5])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([1, 6, 3, 3])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([4, 4, 5, 6])
# Predicted: tensor([0, 2, 8, 8])
# True label:tensor([9, 8, 3, 3])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([1, 0, 2, 1])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([4, 4, 4, 8])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([4, 9, 0, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([9, 5, 0, 6])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([0, 5, 0, 3])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([9, 8, 3, 6])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([1, 9, 4, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([6, 4, 5, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([1, 6, 8, 5])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([9, 4, 5, 3])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([8, 8, 1, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 8, 9, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 6, 2, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([9, 3, 2, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([8, 5, 9, 2])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 1, 6, 3])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 2, 7, 2])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([1, 2, 0, 3])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([0, 4, 8, 5])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 8, 5, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([7, 8, 1, 5])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([9, 8, 0, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([0, 9, 3, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([5, 7, 9, 6])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([0, 7, 1, 5])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([5, 9, 5, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([6, 2, 4, 5])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 7, 4, 2])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([2, 9, 9, 6])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([2, 1, 3, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([1, 8, 7, 9])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([1, 8, 9, 3])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([7, 7, 7, 1])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 4, 4, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([2, 4, 5, 2])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([8, 9, 6, 8])
# Predicted: tensor([2, 8, 2, 0])
# True label:tensor([6, 0, 7, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([5, 0, 1, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([6, 0, 4, 9])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([2, 2, 6, 7])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([1, 0, 5, 0])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 2, 8, 6])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([3, 6, 1, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([4, 8, 7, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([1, 7, 8, 2])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([4, 4, 4, 4])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([1, 8, 6, 7])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([2, 9, 4, 5])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([0, 6, 3, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 2, 0, 7])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([2, 4, 0, 3])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([1, 0, 8, 1])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 7, 2, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([3, 1, 2, 7])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([0, 0, 0, 6])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([2, 7, 2, 8])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([3, 6, 3, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([9, 7, 3, 5])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([4, 9, 6, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([5, 0, 6, 8])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([4, 0, 4, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([0, 4, 1, 6])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([4, 3, 7, 1])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([3, 6, 4, 1])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([1, 5, 6, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 3, 4, 1])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 4, 9, 8])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([8, 4, 5, 5])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([6, 7, 3, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([1, 0, 5, 3])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([7, 0, 1, 1])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([8, 3, 2, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([5, 9, 6, 3])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([8, 1, 0, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([6, 2, 4, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([3, 4, 2, 1])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([9, 1, 7, 9])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 7, 6, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([5, 8, 8, 2])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([6, 4, 6, 3])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 6, 4, 0])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([3, 9, 8, 4])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([0, 8, 4, 3])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([9, 7, 1, 1])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 5, 1, 9])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([4, 4, 2, 4])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 6, 7, 1])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 0, 7, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([5, 8, 1, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([2, 3, 4, 8])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 8, 4, 8])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([1, 8, 9, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([0, 6, 0, 2])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 7, 3, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 1, 3, 5])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([9, 3, 0, 5])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([0, 5, 8, 7])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([3, 6, 2, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([0, 0, 9, 3])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 5, 8, 1])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([1, 2, 6, 6])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([6, 8, 6, 6])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([3, 3, 9, 5])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([4, 3, 3, 1])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([8, 1, 5, 2])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([6, 0, 7, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 2, 7, 1])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([7, 6, 1, 6])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([2, 6, 6, 7])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([0, 4, 9, 3])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([2, 5, 0, 8])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 2, 6, 7])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([4, 2, 1, 1])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 3, 5, 5])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([2, 6, 2, 1])
# Predicted: tensor([0, 8, 2, 2])
# True label:tensor([8, 0, 3, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([3, 4, 2, 9])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([2, 8, 9, 6])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 0, 6, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([5, 4, 7, 8])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([1, 6, 3, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([2, 9, 4, 3])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([5, 1, 2, 6])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([0, 1, 1, 0])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 6, 9, 9])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([0, 1, 2, 4])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([6, 7, 6, 1])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 7, 7, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([7, 6, 5, 1])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([7, 0, 0, 9])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([2, 1, 6, 2])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([2, 5, 8, 5])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 7, 8, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 9, 0, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([1, 3, 8, 2])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([8, 2, 0, 6])
# Predicted: tensor([2, 8, 8, 8])
# ...
# True label:tensor([6, 8, 1, 8])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([2, 1, 8, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([7, 1, 9, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([8, 0, 9, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([1, 0, 8, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([4, 6, 8, 2])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([2, 5, 5, 0])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([6, 6, 9, 8])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 1, 0, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([4, 8, 3, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([7, 7, 5, 9])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([2, 5, 4, 4])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([9, 9, 4, 8])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([7, 6, 9, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([4, 0, 4, 8])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([0, 1, 9, 2])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 6, 7, 1])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([8, 5, 0, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 4, 1, 1])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 8, 8, 9])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([1, 2, 6, 0])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([5, 2, 5, 6])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 3, 6, 1])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([8, 6, 1, 5])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([0, 3, 3, 1])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([9, 2, 8, 7])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([8, 2, 3, 6])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([2, 5, 0, 9])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([0, 7, 1, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 9, 6, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([6, 7, 5, 4])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([6, 3, 3, 6])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([1, 6, 0, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 8, 2, 9])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([6, 2, 5, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([7, 2, 6, 5])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 0, 9, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 0, 2, 3])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([5, 6, 4, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([4, 6, 9, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 3, 2, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([0, 3, 9, 2])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([2, 8, 1, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([2, 4, 9, 3])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([6, 2, 0, 6])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([7, 0, 5, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([6, 3, 1, 3])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([0, 9, 5, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([3, 7, 0, 6])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 9, 0, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 5, 6, 8])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([2, 1, 0, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([6, 5, 9, 3])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([5, 0, 6, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 4, 6, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 3, 8, 6])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([3, 8, 9, 4])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([0, 8, 8, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 0, 7, 7])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([0, 3, 6, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([1, 5, 9, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([2, 8, 9, 0])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([1, 0, 5, 5])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([2, 2, 8, 2])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([3, 6, 7, 4])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 3, 7, 4])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([5, 8, 8, 3])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([9, 5, 0, 6])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([2, 6, 3, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([6, 9, 2, 5])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 5, 6, 3])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([1, 7, 8, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([4, 7, 3, 3])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([8, 6, 0, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([2, 8, 5, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([9, 6, 6, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([2, 0, 1, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([9, 3, 8, 2])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([1, 9, 5, 8])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([4, 8, 2, 3])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([5, 3, 6, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([9, 2, 6, 2])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([9, 8, 0, 5])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 2, 4, 5])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([2, 1, 0, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([4, 4, 2, 7])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([4, 0, 6, 6])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([1, 5, 4, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([1, 9, 9, 5])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([6, 5, 2, 9])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([6, 6, 4, 5])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([4, 8, 9, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([9, 5, 5, 5])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([7, 9, 3, 3])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([8, 4, 3, 9])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([3, 1, 0, 2])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([5, 2, 8, 7])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 7, 7, 7])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([9, 2, 0, 0])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([6, 7, 6, 1])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([8, 0, 3, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([5, 0, 5, 6])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([9, 1, 1, 2])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([6, 8, 9, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([7, 5, 8, 6])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([1, 4, 0, 1])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([8, 4, 3, 4])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([7, 9, 3, 7])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([5, 5, 0, 9])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([1, 2, 1, 2])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([7, 6, 0, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([3, 2, 1, 1])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([7, 8, 1, 6])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([5, 9, 0, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 5, 3, 8])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([8, 2, 8, 5])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([7, 0, 7, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([9, 6, 9, 2])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 4, 8, 5])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([2, 0, 1, 6])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([6, 1, 7, 6])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([1, 7, 7, 8])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([5, 7, 0, 6])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([4, 2, 1, 6])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([8, 0, 0, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([7, 5, 9, 1])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([0, 4, 3, 7])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([6, 6, 3, 1])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([8, 4, 7, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([5, 9, 3, 1])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([8, 1, 9, 2])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([9, 6, 2, 2])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([1, 8, 3, 9])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([8, 2, 0, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([8, 4, 5, 1])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([2, 2, 6, 4])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([1, 8, 5, 7])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([7, 7, 3, 5])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([5, 7, 9, 9])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 2, 8, 2])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([1, 3, 3, 4])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([8, 9, 4, 0])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 6, 2, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 0, 6, 1])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([6, 5, 2, 9])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([7, 2, 8, 7])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([3, 7, 8, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([2, 1, 7, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([8, 8, 5, 0])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([2, 6, 6, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([2, 6, 5, 0])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([1, 5, 5, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 1, 9, 8])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([7, 1, 2, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([0, 9, 3, 1])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([9, 0, 4, 6])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([6, 5, 9, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([4, 2, 7, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([8, 1, 4, 2])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([3, 7, 8, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([6, 4, 5, 1])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([2, 9, 3, 5])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([8, 0, 1, 9])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([6, 7, 3, 7])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([4, 4, 0, 6])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([2, 1, 1, 3])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([0, 7, 0, 5])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([9, 8, 9, 3])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([7, 9, 9, 4])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 8, 0, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([6, 4, 0, 6])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([8, 1, 6, 1])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([6, 3, 2, 7])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 7, 0, 4])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([3, 4, 4, 5])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([7, 9, 2, 5])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([2, 4, 5, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([1, 7, 6, 7])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([6, 0, 0, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([5, 1, 1, 2])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([4, 6, 9, 8])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([1, 6, 1, 6])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([8, 5, 4, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([4, 0, 4, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([3, 8, 5, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([8, 6, 2, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([0, 4, 4, 0])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([8, 7, 5, 2])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([8, 9, 2, 9])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([5, 9, 2, 1])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([0, 4, 1, 7])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([7, 1, 7, 3])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([5, 8, 7, 2])
# Predicted: tensor([8, 8, 2, 2])
# True label:tensor([5, 1, 5, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([0, 6, 0, 1])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([2, 4, 4, 8])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 3, 2, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([3, 5, 1, 3])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([3, 0, 5, 1])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 3, 1, 8])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 8, 4, 2])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([0, 0, 7, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([1, 3, 9, 0])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([2, 8, 1, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([8, 8, 3, 0])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 5, 7, 5])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([4, 7, 7, 6])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([1, 8, 1, 9])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([7, 0, 3, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([6, 5, 5, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 9, 4, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([9, 5, 1, 7])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([2, 1, 5, 2])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([8, 3, 3, 6])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([7, 1, 3, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([4, 5, 7, 0])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([6, 7, 3, 3])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([7, 8, 8, 2])
# Predicted: tensor([2, 2, 8, 2])
# True label:tensor([5, 6, 9, 7])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([0, 2, 9, 3])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([0, 5, 5, 6])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 1, 4, 1])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([5, 6, 4, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([4, 0, 3, 3])
# Predicted: tensor([2, 8, 8, 8])
# True label:tensor([6, 3, 0, 8])
# Predicted: tensor([8, 2, 8, 8])
# True label:tensor([6, 7, 5, 5])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([7, 0, 7, 9])
# Predicted: tensor([8, 8, 8, 2])
# True label:tensor([4, 4, 2, 9])
# Predicted: tensor([2, 2, 2, 2])
# True label:tensor([1, 7, 1, 8])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([8, 8, 5, 8])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([3, 8, 9, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([0, 0, 2, 1])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([8, 4, 4, 0])
# Predicted: tensor([8, 2, 2, 8])
# True label:tensor([0, 9, 5, 3])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([1, 5, 1, 3])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([5, 0, 2, 6])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([1, 5, 3, 0])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([8, 6, 9, 6])
# Predicted: tensor([8, 2, 2, 2])
# True label:tensor([9, 6, 0, 4])
# Predicted: tensor([2, 8, 8, 2])
# True label:tensor([1, 6, 6, 4])
# Predicted: tensor([2, 2, 8, 8])
# True label:tensor([9, 1, 4, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([7, 8, 2, 6])
# Predicted: tensor([2, 8, 2, 8])
# True label:tensor([2, 9, 7, 8])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([5, 6, 9, 6])
# Predicted: tensor([8, 8, 2, 8])
# True label:tensor([0, 0, 8, 1])
# Predicted: tensor([8, 2, 8, 2])
# True label:tensor([3, 2, 7, 5])
# Predicted: tensor([2, 2, 2, 8])
# True label:tensor([8, 4, 5, 6])
# Predicted: tensor([8, 8, 8, 8])
# True label:tensor([8, 9, 1, 9])
# Predicted: tensor([2, 8, 2, 2])
# True label:tensor([1, 8, 1, 5])
# Predicted: tensor([8, 2, 2, 8])
# The overall accuracy is 12.199999809265137
